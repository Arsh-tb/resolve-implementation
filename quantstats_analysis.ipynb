# %%
import quantstats_tb as qs
import pandas as pd
df = pd.read_excel(r"D:\Arsh\resolve-implementation\Portfolios\final_result\combined_results.xlsx")
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

# Filter data to start from March 2014
start_date = '2014-03-01'
df = df[df.index >= start_date]

# df = pd.pivot_table(df, index='date', columns='strategy', values='index_levels')
qs.reports.html(df,periods_per_year=12,rf = 0.063, output=r"D:\Arsh\resolve-implementation\Portfolios\final_result\Asset_allocation_monthly.html")
# Out:
# HTML report saved to: D:\Arsh\resolve-implementation\Portfolios\final_result\Asset_allocation_monthly.html
#                           TC0.1_equal_weight equal_weight_TC0  \
# Metric
# Risk-Free Rate                          6.3%             6.3%
# Time in Market                        100.0%           100.0%
#
# Total Return                            215%             216%
# CAGR% (Annual Return)                 10.83%           10.86%
#
# Sharpe                                  0.52             0.52
# RoMaD                                   1.48             1.49
# Prob. Sharpe Ratio                    99.99%           99.99%
# Smart Sharpe                            0.51             0.51
# Sortino                                 0.92             0.92
# Smart Sortino                           0.89              0.9
# Sortino/√2                              0.65             0.65
# Smart Sortino/√2                        0.63             0.64
# ...
